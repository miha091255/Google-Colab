# %% [markdown]
# <a href="https://colab.research.google.com/github/miha091255/Google-Colab/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(r"image.png")
plt.imshow(img)

# %%
import numpy as np

img_gray = np.mean(img, axis=-1)
plt.imshow(img_gray, cmap='gray')

# %%
im = img_gray.astype('int32')
dx = ndimage.sobel(im, 1)  
dy = ndimage.sobel(im, 0)  
mag = numpy.hypot(dx, dy)  
mag *= 255.0 / numpy.max(mag)  
plt.imshow(mag, cmap='gray')
